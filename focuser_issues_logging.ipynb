# %%
import astropy.io.fits as fits
import numpy as np
import matplotlib.pyplot as plt
import sys
import glob
import os
import ccdproc

# %%
base_dir = 'recenter_images'
imgs = ccdproc.ImageFileCollection(base_dir)

# %%
# Get header for recenter_images\Temp2024-04-16T04-01-15.490.fts
imgpath = os.path.join(base_dir, 'Temp2024-04-16T04-01-15.490.fts')
hdr = fits.getheader(imgpath)
hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                   16 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 2048
# NAXIS2  =                 2048
# DATE-OBS= '2024-04-16T04:01:06.980' / [ISO 8601] UTC date/time of exposure start
# EXPTIME =   3.00000000000E+000 / [sec] Duration of exposure
# EXPOSURE=   3.00000000000E+000 / [sec] Duration of exposure
# SET-TEMP=  -65.629997253417969 /CCD temperature setpoint in C
# CCD-TEMP=  -64.969001770019531 /CCD temperature at start of exposure in C
# XPIXSZ  =   13.500000000000000 /Pixel Width in microns (after binning)
# YPIXSZ  =   13.500000000000000 /Pixel Height in microns (after binning)
# XBINNING=                    1 / Binning level along the X-axis
# YBINNING=                    1 / Binning level along the Y-axis
# XORGSUBF=                    0 /Subframe X position in binned pixels
# ...
